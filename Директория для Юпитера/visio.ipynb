# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv('2019.csv',sep=',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
df[['Generosity','Social support']].plot(kind='area')
plt.title('Зависимость уровня щедрости от страны')
plt.xlabel('Уровень социальной поддержки')
plt.ylabel('Уровень щедрости')
#Можно сделать вывод, что уровень щедрости зависит от уровня социальной поддержки (видно при сравнении пиков и провалов графиков).
# Out:
# Text(0, 0.5, 'Уровень щедрости')

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 20,6

# %%
df.style.bar(align='mid')
#Можно сделать вывод, что уровень счастья зависит от качества социальной поддержки,свободы выбора и продолжительности жизни.
# Out:
# <style  type="text/css" >
# #T_f3ad7_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0.6%);
#         }#T_f3ad7_row0_col2,#T_f3ad7_row3_col4,#T_f3ad7_row28_col3,#T_f3ad7_row33_col5,#T_f3ad7_row33_col8,#T_f3ad7_row40_col6,#T_f3ad7_row130_col7,#T_f3ad7_row155_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_f3ad7_row0_col3,#T_f3ad7_row39_col2,#T_f3ad7_row68_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 79.6%, transparent 79.6%);
#         }#T_f3ad7_row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 97.7%, transparent 97.7%);
#         }#T_f3ad7_row0_col5,#T_f3ad7_row17_col5{
#             width:  10em;
#              height:  80%;
# ...

# %%
df_new = df[['GDP per capita','Country or region','Perceptions of corruption']].sort_values(by='Perceptions of corruption',ascending=False)

# %%
df_pie=df_new[['GDP per capita','Country or region']].head(5)

# %%
pie=df_pie['GDP per capita'].plot(kind='pie')
plt.title('ВВП стран с наибольшими представлениями о коррупции')
plt.labels=df_pie['Country or region']
#Можно сделать вывод, что в целом ВВП и представления о коррупции мало связаны

# %%
df_sort=df.sort_values(by='Score')
sns.regplot(data=df_sort,x='Healthy life expectancy',y='Country or region',color='red',marker='^')
plt.title('Уровень ожидаемой продолжительности жтзни в зависиости от страны')
#Прослеживается некоторая зависимость между продолжительностью жизни и уровнем счастья
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-333f3820194d> in <module>
#       1 df_sort=df.sort_values(by='Score')
# ----> 2 sns.regplot(data=df_sort,x='Healthy life expectancy',y='Country or region',color='red',marker='^')
#       3 plt.title('Уровень ожидаемой продолжительности жтзни в зависиости от страны')
#       4 #Прослеживается некоторая зависимость между продолжительностью жизни и уровнем счастья
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
