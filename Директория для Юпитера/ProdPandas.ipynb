# %%
import pandas as pd

# %%
df = pd.read_csv('visit_log.csv',sep=';')
df.head()
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
#
#       user_id traffic_source
# 0  b1613cc09f         yandex
# 1  4c3ec14bee         direct
# 2  a8c40697fb         yandex
# 3  521ac1d6a0         yandex
# 4  d7323c571c         yandex

# %%
df['source_type']=df.apply(choice,axis=1)

# %%
df.head()
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
#
#       user_id traffic_source source_type
# 0  b1613cc09f         yandex     organic
# 1  4c3ec14bee         direct      direct
# 2  a8c40697fb         yandex     organic
# 3  521ac1d6a0         yandex     organic
# 4  d7323c571c         yandex     organic

# %%
def choice(row):
    row.traffic_source.lower()
    row.region.lower()
    if row.traffic_source == 'yandex' or row.traffic_source == 'google':
        answer='organic'
    elif (row.traffic_source=='paid'and row.region=='russia') or (row.traffic_source=='email'and row.region=='russia'):
        answer='ad'
    elif (row.traffic_source=='paid'and row.region!='russia') or (row.traffic_source=='email'and row.region!='russia'):
        answer='other'
    else:
        answer=row.traffic_source
    return answer

# %%
from urllib import parse

# %%
url =  pd.read_csv('URLs.txt')
url
# Out:
#                                                   url
# 0                                             /world/
# 1                                            /latest/
# 2                                       /?updated=top
# 3   /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# ..                                                ...
# 88  /cis/35984145-kreml-prokommentiroval-soobschen...
# 89  /video/36071019-olimpiyskie-obekty-rio-prevrat...
# 90  /science/36151301-nazvano-posledstvie-zloupotr...
# 91  /incidents/36027330-vospitatelnitsu-zatravili-...
# 92  /world/36103095-dominikanskih-zhurnalistov-ubi...
#
# [93 rows x 1 columns]

# %%
url.apply(func,axis=1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#       ...
# 88    None
# 89    None
# 90    None
# 91    None
# 92    None
# Length: 93, dtype: object

# %%
answer
# Out:
# {'/36188461-': '/politics/36188461-s-marta-zhizn-rossiyan-suschestvenno-izmenitsya-iz-za-novyh-zakonov/',
#  '/36007585-': '/world/36007585-tramp-pridumal-kak-reshit-ukrainskiy-vopros/?smi2=1',
#  '/36157853-': '/science/36157853-nasa-sobiraet-ekstrennuyu-press-konferentsiyu-na-temu-vnezemnoy-zhizni/',
#  '/36001498-': '/video/36001498-poyavilis-pervye-podrobnosti-gibeli-natali-melamed/',
#  '/36131117-': '/middleeast/36131117-divizion-s-400-ne-zametil-ataki-f-35-pod-damaskom/?smi2=1',
#  '/36065674-': '/economics/36065674-rossiyane-vozmutilis-minimalnymi-zarplatami-v-stranah-es/',
#  '/36118047-': '/politics/36118047-otets-24-detey-potreboval-izvineniy-ot-soloveva/',
#  '/36194479-': '/travel/36194479-v-sheremetevo-passazhiry-ustroili-bunt/',
#  '/35638742-': '/politics/35638742-nesolidno-mariya-zaharova-sdelala-neozhidannoe-priznanie/',
#  '/36012692-': '/video/36012692-tramp-otkrestilsya-ot-rossii-i-putina/',
#  '/36174817-': '/starlife/36174817-guzeeva-rasstalas-s-muzhem/',
# ...

# %%
[]!=re.findall(r'\d+','jhfjfhgf')
# Out:
# False

# %%
import re

# %%
answer={}
def func(row):
    news=re.findall(r'/\d{8}\-',row.url)
    if []!=news:
        answer[news[0]]=row.url

# %%
rp=pd.read_csv('ml-latest-small/ratings.csv',sep=',')

# %%
rp.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
rp.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
n_rp=rp.groupby('userId').count().reset_index()
new_rp=n_rp.loc[n_rp.rating>=100]

# %%
new_rp.apply(tab,axis=1)
# Out:
# 3      None
# 4      None
# 7      None
# 14     None
# 16     None
#        ...
# 655    None
# 658    None
# 663    None
# 664    None
# 670    None
# Length: 263, dtype: object

# %%
def tab(row):
    time=rp[rp.userId==row['userId']]['timestamp'].max()-rp[rp.userId==row['userId']]['timestamp'].min()
    table[row['userId']]=time

# %%
table = {'UserId':'lifetime'}

    #print(rp[rp['userId'==user]].max('timestamp')-rp[rp['userId'==user]].min('timestamp'))

# %%
table
# Out:
# {'UserId': 'lifetime',
#  4: 203560,
#  5: 2101,
#  8: 85187,
#  15: 471393496,
#  17: 8053,
#  19: 5282,
#  21: 1365432,
#  22: 91491,
#  23: 18342129,
#  26: 20267261,
#  30: 115852276,
#  33: 4332211,
#  34: 2835,
#  36: 5949290,
#  38: 59971665,
#  41: 15930495,
#  43: 13885,
#  48: 136315977,
#  56: 8564120,
#  57: 4323,
#  61: 1374418,
#  67: 4136,
#  68: 152083904,
#  72: 2945466,
#  73: 220585493,
#  75: 22560475,
#  77: 21944613,
#  78: 89416228,
#  81: 11772,
#  83: 2595,
#  84: 198892,
#  85: 6316,
#  86: 3070,
#  88: 19631393,
#  91: 16397,
#  92: 1201,
#  93: 263753,
#  94: 615532,
#  95: 9239510,
#  97: 1777,
#  99: 106237866,
#  102: 5201447,
#  105: 113865791,
#  110: 1148,
#  111: 2507915,
#  118: 14255111,
#  119: 76737913,
#  120: 42072174,
#  125: 25295470,
#  128: 8523,
#  130: 10659002,
#  133: 20371,
#  134: 3075,
#  148: 175485,
#  149: 172744,
#  150: 224803872,
#  152: 49683,
#  157: 79469144,
#  159: 1572,
#  160: 3855,
#  165: 8589450,
#  168: 13330,
# ...

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)
rzd
# Out:
#    client_id  rzd_revenue
# 0        111         1093
# 1        112         2810
# 2        113        10283
# 3        114         5774
# 4        115          981

# %%
auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)
auto
# Out:
#    client_id  auto_revenue
# 0        113         57483
# 1        114            83
# 2        115           912
# 3        116          4834
# 4        117            98

# %%
air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)
air
# Out:
#    client_id  air_revenue
# 0        115           81
# 1        116            4
# 2        117           13
# 3        118          173

# %%
client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1', 
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)
client_base
# Out:
#    client_id          address
# 0        111  Комсомольская 4
# 1        112   Энтузиастов 8а
# 2        113  Левобережная 1а
# 3        114          Мира 14
# 4        115        ЗЖБИиДК 1
# 5        116    Строителей 18
# 6        117  Панфиловская 33
# 7        118     Мастеркова 4

# %%
joined = rzd.merge(auto,how='outer',on='client_id')
full=joined.merge(air,how='outer',on='client_id')
full_add=full.merge(client_base,how='outer',on='client_id')
full_add
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue          address
# 0        111       1093.0           NaN          NaN  Комсомольская 4
# 1        112       2810.0           NaN          NaN   Энтузиастов 8а
# 2        113      10283.0       57483.0          NaN  Левобережная 1а
# 3        114       5774.0          83.0          NaN          Мира 14
# 4        115        981.0         912.0         81.0        ЗЖБИиДК 1
# 5        116          NaN        4834.0          4.0    Строителей 18
# 6        117          NaN          98.0         13.0  Панфиловская 33
# 7        118          NaN           NaN        173.0     Мастеркова 4

# %%
# ?rzd.merge
